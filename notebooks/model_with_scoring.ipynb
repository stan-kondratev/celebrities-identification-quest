# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf

import os

from sklearn.neighbors import NearestNeighbors

from sklearn.manifold import TSNE
import plotly.express as px
from cuda import cuda

# %%
# !pip install -U deepface

# %%
from deepface import DeepFace

# %%
folder_path = '../raw_data/output_imdb_top100_trans' # provide your path here

file_list = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))]
for n, i in enumerate(file_list): print(n, os.path.splitext(os.path.basename(i))[0])
# Out:
# 0 faye_dunaway_face_aligned
# 1 blake_lively_face_aligned
# 2 vera_farmiga_face_aligned
# 3 gregory_peck_face_aligned
# 4 alyson_hannigan_face_aligned
# 5 elizabeth_banks_face_aligned
# 6 christopher_walken_face_aligned
# 7 rooney_mara_face_aligned
# 8 anne_hathaway_face_aligned
# 9 nicole_kidman_face_aligned
# 10 sidney_poitier_face_aligned
# 11 alan_arkin_face_aligned
# 12 marlon_brando_face_aligned
# 13 robert_redford_face_aligned
# 14 ben_kingsley_face_aligned
# 15 burt_lancaster_face_aligned
# 16 cate_blanchett_face_aligned
# 17 bill_murray_face_aligned
# 18 tom_cruise_face_aligned
# 19 gary_oldman_face_aligned
# 20 rosamund_pike_face_aligned
# 21 will_smith_face_aligned
# 22 jim_carrey_face_aligned
# 23 tom_hanks_face_aligned
# 24 jeff_bridges_face_aligned
# 25 meryl_streep_face_aligned
# 26 emma_stone_face_aligned
# 27 charles_chaplin_face_aligned
# 28 daniel_day-lewis_face_aligned
# 29 geoffrey_rush_face_aligned
# 30 richard_burton_face_aligned
# 31 natalie_portman_face_aligned
# 32 emily_blunt_face_aligned
# 33 sean_penn_face_aligned
# 34 peter_o'toole_face_aligned
# 35 chloe_grace_moretz_face_aligned
# 36 jason_robards_face_aligned
# 37 edward_g._robinson_face_aligned
# 38 steve_mcqueen_face_aligned
# 39 robert_duvall_face_aligned
# 40 angelina_jolie_face_aligned
# 41 carrie_fisher_face_aligned
# 42 jessica_chastain_face_aligned
# 43 hugh_jackman_face_aligned
# 44 brie_larson_face_aligned
# 45 tilda_swinton_face_aligned
# 46 javier_bardem_face_aligned
# 47 gary_cooper_face_aligned
# 48 grace_kelly_face_aligned
# 49 michael_caine_face_aligned
# 50 cary_grant_face_aligned
# 51 kevin_spacey_face_aligned
# 52 laurence_olivier_face_aligned
# 53 lea_seydoux_face_aligned
# 54 benicio_del_toro_face_aligned
# 55 milla_jovovich_face_aligned
# 56 paul_newman_face_aligned
# 57 james_dean_face_aligned
# 58 bibi_andersson_face_aligned
# 59 naomi_watts_face_aligned
# 60 james_cagney_face_aligned
# 61 christopher_plummer_face_aligned
# 62 hilary_swank_face_aligned
# 63 marion_cotillard_face_aligned
# 64 hailee_steinfeld_face_aligned
# 65 marlene_dietrich_face_aligned
# 66 julianne_moore_face_aligned
# 67 vivien_leigh_face_aligned
# 68 jennifer_connelly_face_aligned
# 69 philip_seymour_hoffman_face_aligned
# 70 morgan_freeman_face_aligned
# 71 kirsten_dunst_face_aligned
# 72 edward_norton_face_aligned
# 73 cameron_diaz_face_aligned
# 74 peter_sellers_face_aligned
# 75 humphrey_bogart_face_aligned
# 76 uma_thurman_face_aligned
# 77 tommy_lee_jones_face_aligned
# 78 sally_hawkins_face_aligned
# 79 evangeline_lilly_face_aligned
# 80 orson_welles_face_aligned
# 81 audrey_tautou_face_aligned
# 82 anthony_hopkins_face_aligned
# 83 keira_knightley_face_aligned
# 84 jeremy_irons_face_aligned
# 85 michael_douglas_face_aligned
# 86 buster_keaton_face_aligned
# 87 elliot_page_face_aligned
# 88 christoph_waltz_face_aligned
# 89 jamie_foxx_face_aligned
# 90 jennifer_jason_leigh_face_aligned
# 91 robert_de_niro_face_aligned
# 92 robert_downey_jr._face_aligned
# 93 joe_pesci_face_aligned
# 94 saoirse_ronan_face_aligned
# 95 brad_pitt_face_aligned
# 96 ellen_burstyn_face_aligned
# 97 jennifer_aniston_face_aligned
# 98 woody_allen_face_aligned
# 99 charlize_theron_face_aligned
# 100 liv_ullmann_face_aligned
# 101 anthony_quinn_face_aligned
# 102 shelley_duvall_face_aligned
# 103 jack_nicholson_face_aligned
# 104 carey_mulligan_face_aligned
# 105 jennifer_lawrence_face_aligned
# 106 kaya_scodelario_face_aligned
# 107 alec_guinness_face_aligned
# 108 colin_firth_face_aligned
# 109 ingrid_bergman_face_aligned
# 110 elizabeth_olsen_face_aligned
# 111 frances_mcdormand_face_aligned
# 112 kirk_douglas_face_aligned
# 113 viola_davis_face_aligned
# 114 helena_bonham_carter_face_aligned
# 115 spencer_tracy_face_aligned
# 116 rachel_weisz_face_aligned
# 117 robert_mitchum_face_aligned
# 118 heath_ledger_face_aligned
# 119 melanie_laurent_face_aligned
# 120 clint_eastwood_face_aligned
# 121 henry_fonda_face_aligned
# 122 felicity_jones_face_aligned
# 123 margot_robbie_face_aligned
# 124 kate_mara_face_aligned
# 125 al_pacino_face_aligned
# 126 joan_allen_face_aligned
# 127 ralph_fiennes_face_aligned
# 128 robin_williams_face_aligned
# 129 katheryn_winnick_face_aligned
# 130 sean_connery_face_aligned
# 131 diane_keaton_face_aligned
# 132 gloria_swanson_face_aligned
# 133 julia_louis-dreyfus_face_aligned
# 134 alec_guinness_res_face_aligned
# 135 gene_hackman_face_aligned
# 136 johnny_depp_face_aligned
# 137 samuel_l._jackson_face_aligned
# 138 charlton_heston_face_aligned
# 139 michelle_pfeiffer_face_aligned
# 140 julie_delpy_face_aligned
# 141 adele_exarchopoulos_face_aligned
# 142 demi_moore_face_aligned
# 143 denzel_washington_face_aligned
# 144 jodie_foster_face_aligned
# 145 clark_gable_face_aligned
# 146 sigourney_weaver_face_aligned
# 147 jack_lemmon_face_aligned
# 148 james_stewart_face_aligned
# 149 john_wayne_face_aligned
# 150 harrison_ford_face_aligned
# 151 gene_kelly_face_aligned
# 152 bette_davis_face_aligned
# 153 john_goodman_face_aligned
# 154 ian_mckellen_face_aligned
# 155 sharon_stone_face_aligned
# 156 peter_finch_face_aligned
# 157 maggie_gyllenhaal_face_aligned
# 158 emma_watson_face_aligned
# 159 albert_finney_face_aligned
# 160 emmy_rossum_face_aligned
# 161 katherine_parkinson_face_aligned
# 162 olga_kurylenko_face_aligned
# 163 maggie_smith_face_aligned
# 164 diane_kruger_face_aligned
# 165 janet_leigh_face_aligned
# 166 robin_wright_face_aligned
# 167 matthew_mcconaughey_face_aligned
# 168 scarlett_johansson_face_aligned
# 169 talia_shire_face_aligned
# 170 alan_rickman_face_aligned
# 171 mia_farrow_face_aligned
# 172 matt_damon_face_aligned
# 173 russell_crowe_face_aligned
# 174 mel_gibson_face_aligned
# 175 jon_voight_face_aligned
# 176 kate_winslet_face_aligned
# 177 dustin_hoffman_face_aligned
# 178 lauren_cohan_face_aligned
# 179 daisy_ridley_face_aligned
# 180 anna_kendrick_face_aligned
# 181 william_holden_face_aligned
# 182 rachel_mcadams_face_aligned
# 183 liam_neeson_face_aligned
# 184 don_cheadle_face_aligned
# 185 alicia_vikander_face_aligned
# 186 joaquin_phoenix_face_aligned
# 187 martin_sheen_face_aligned
# 188 julia_roberts_face_aligned
# 189 octavia_spencer_face_aligned
# 190 leonardo_dicaprio_face_aligned
# 191 eva_green_face_aligned
# 192 amy_adams_face_aligned
# 193 christian_bale_face_aligned

# %% [markdown]
# There are several models available in DeepFace:
# - VGG-Face
# - FaceNet (128D, 512D)
# - OpenFace
# - DeepID
# - DeepFace
# - ArcFace
#
# They are different in performance

# %%
deepface_vectors = np.array([np.array(DeepFace.represent(i, model_name='DeepFace', enforce_detection=False)[0]['embedding']) for i in file_list])

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.12.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
knn_deepface = NearestNeighbors(n_neighbors=len(deepface_vectors), n_jobs=-1)

knn_deepface.fit(deepface_vectors)

deepface_distances, deepface_indices = knn_deepface.kneighbors(deepface_vectors)

# %%
deepface_df = pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list])\
        .rename(columns={0:'name'})
deepface_df = pd.concat([deepface_df, pd.DataFrame(deepface_indices[:,1:])], axis=1)#.rename(columns={0:'vector'})

# %%
deepface_df[deepface_df.columns[1:]] = deepface_df[deepface_df.columns[1:]].applymap(lambda i: deepface_df.name.iloc[i])
deepface_df.head()
# Out:
#                 name                     0                1              2  \
# 0      ellen_burstyn           colin_firth  michael_douglas  kirsten_dunst
# 1      julia_roberts  jennifer_jason_leigh        al_pacino     demi_moore
# 2       meryl_streep          gene_hackman     martin_sheen   jeff_bridges
# 3        jack_lemmon          vera_farmiga  tommy_lee_jones  russell_crowe
# 4  jennifer_lawrence    scarlett_johansson     robin_wright  russell_crowe
#
#                      3                  4                5               6  \
# 0    michelle_pfeiffer  maggie_gyllenhaal     diane_kruger      matt_damon
# 1  julia_louis-dreyfus     robert_de_niro       alan_arkin   ralph_fiennes
# 2           john_wayne          al_pacino  anthony_hopkins    hugh_jackman
# 3       amanda_plummer       gene_hackman   morgan_freeman    meryl_streep
# 4     benicio_del_toro      robert_duvall     blake_lively  morgan_freeman
#
#                  7                    8  ...                  190  \
# 0    saoirse_ronan       cate_blanchett  ...  adele_exarchopoulos
# 1   dustin_hoffman         robin_wright  ...       shelley_duvall
# 2  tommy_lee_jones  julia_louis-dreyfus  ...         orson_welles
# 3     jeff_bridges        peter_o'toole  ...        buster_keaton
# 4     sharon_stone      alicia_vikander  ...          bette_davis
#
#                 191                  192               193               194  \
# 0  charles_laughton           emma_stone  marlene_dietrich   joaquin_phoenix
# 1  laurence_olivier      joaquin_phoenix  marlene_dietrich  charles_laughton
# 2    bibi_andersson    virginia_cherrill   joaquin_phoenix    ingrid_bergman
# 3      orson_welles          janet_leigh    felicity_jones   joaquin_phoenix
# 4  charles_laughton  adele_exarchopoulos  marlene_dietrich   joaquin_phoenix
#
#                  195                196             197             198  \
# 0     milla_jovovich  virginia_cherrill     liv_ullmann  felicity_jones
# 1        liv_ullmann  virginia_cherrill       kim_novak  felicity_jones
# 2        liv_ullmann   laurence_olivier       kim_novak  felicity_jones
# 3       sean_connery     ingrid_bergman       kim_novak  bibi_andersson
# 4  virginia_cherrill          kim_novak  milla_jovovich  felicity_jones
#
#                 199
# 0         kim_novak
# 1    milla_jovovich
# 2    milla_jovovich
# 3  laurence_olivier
# 4       liv_ullmann
#
# [5 rows x 201 columns]

# %%
overall_distances_df = pd.concat([pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list])\
        .rename(columns={0:'name'}), pd.DataFrame(deepface_distances[:,1:])], axis=1).set_index('name').T

overall_indices_df = pd.concat([pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list])\
        .rename(columns={0:'name'}), pd.DataFrame(deepface_indices[:,1:])], axis=1).set_index('name').T

overall_scoring_df = overall_distances_df.copy()

for column in overall_scoring_df.columns:
    overall_scoring_df[column] = overall_scoring_df[column].apply(lambda x: round((x- overall_scoring_df[column].max())/(overall_scoring_df[column].min()-overall_scoring_df[column].max())*100, 1) - 1 if x >1.01 else x).apply(abs)

overall_scoring_df.head(10)
overall_scoring_df.to_csv("../raw_data/scoring.csv")

# %%
names_df = deepface_df.set_index('name').T
names_df.head()
names_df.to_csv("../raw_data/names.csv")

# %%
hidden_celebrity = 'saoirse_ronan'

# %%
def celeb_and_score_query(celebrity, hidden_celebrity=hidden_celebrity, names_df=names_df, score_df=overall_scoring_df):
    celeb_rank = names_df[hidden_celebrity][names_df[hidden_celebrity] == celebrity].index
    celeb_score = overall_scoring_df[hidden_celebrity].loc[celeb_rank].iloc[0]
    return celebrity, celeb_score

# %%
celeb_and_score_query('hugh_jackman')
# Out:
# ('hugh_jackman', 65.7)

# %%
names_df.head(2)
# Out:
# name    ellen_burstyn         julia_roberts  meryl_streep      jack_lemmon  \
# 0         colin_firth  jennifer_jason_leigh  gene_hackman     vera_farmiga
# 1     michael_douglas             al_pacino  martin_sheen  tommy_lee_jones
#
# name   jennifer_lawrence          kate_mara adele_exarchopoulos  \
# 0     scarlett_johansson  jennifer_connelly      carey_mulligan
# 1           robin_wright        emma_watson          jim_carrey
#
# name  marilyn_monroe  michael_caine    spencer_tracy  ...    eva_green  \
# 0       james_cagney  peter_o'toole  anthony_hopkins  ...  brie_larson
# 1     gloria_swanson  russell_crowe   angelina_jolie  ...  julie_delpy
#
# name           emily_blunt   hugh_jackman  robert_duvall       clark_gable  \
# 0     jennifer_jason_leigh      al_pacino  peter_o'toole      hugh_jackman
# 1                amy_adams  robert_duvall  russell_crowe  jennifer_aniston
#
# name      octavia_spencer      joan_allen      bill_murray   jeremy_irons  \
# 0           russell_crowe   russell_crowe     gene_hackman  russell_crowe
# 1     julia_louis-dreyfus  morgan_freeman  michael_douglas      tom_hanks
#
# name edward_g._robinson
# 0          hugh_jackman
# 1         russell_crowe
#
# [2 rows x 201 columns]

# %%
tsne = TSNE(n_components=3, random_state=0, perplexity=5)
projections = tsne.fit_transform(deepface_vectors, )

plotting_df = pd.concat([deepface_df['name'], pd.DataFrame(projections)], axis=1)

fig = px.scatter_3d(
    plotting_df, x=0, y=1, z=2, hover_data='name'
)
fig.update_traces(marker_size=4)
fig.show()
# Out:
# <div>                            <div id="93d6b911-e079-42d3-b820-ca271cf33b3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93d6b911-e079-42d3-b820-ca271cf33b3a")) {                    Plotly.newPlot(                        "93d6b911-e079-42d3-b820-ca271cf33b3a",                        [{"customdata":[["ellen_burstyn"],["julia_roberts"],["meryl_streep"],["jack_lemmon"],["jennifer_lawrence"],["kate_mara"],["adele_exarchopoulos"],["marilyn_monroe"],["michael_caine"],["spencer_tracy"],["mel_gibson"],["amanda_plummer"],["johnny_depp"],["brad_pitt"],["demi_moore"],["jessica_chastain"],["charlize_theron"],["george_c._scott"],["gene_hackman"],["benicio_del_toro"],["gene_kelly"],["samuel_l._jackson"],["tom_hanks"],["emmy_rossum"],["janet_leigh"],["steve_mcqueen"],["gary_cooper"],["orson_welles"],["maggie_gyllenhaal"],["tommy_lee_jones"],["jeff_bridges"],["naomi_watts"],["alyson_hannigan"],["rachel_weisz"],["ralph_fiennes"],["hailee_steinfeld"],["alan_arkin"],["kirk_douglas"],["jim_carrey"],["joaquin_phoenix"],["robert_redford"],["felicity_jones"],["kim_basinger"],["kirsten_dunst"],["natalie_portman"],["albert_finney"],["matt_damon"],["cameron_diaz"],["sharon_stone"],["charlton_heston"],["grace_kelly"],["julia_louis-dreyfus"],["jodie_foster"],["marion_cotillard"],["gregory_peck"],["humphrey_bogart"],["burt_lancaster"],["marlon_brando"],["margot_robbie"],["james_dean"],["liam_neeson"],["amy_adams"],["chloe_grace_moretz"],["william_holden"],["elizabeth_banks"],["woody_allen"],["leonardo_dicaprio"],["christopher_walken"],["daniel_day-lewis"],["jack_nicholson"],["sean_connery"],["peter_finch"],["ian_mckellen"],["jason_robards"],["angelina_jolie"],["ben_kingsley"],["tom_cruise"],["mia_farrow"],["julianne_moore"],["cary_grant"],["sean_penn"],["blake_lively"],["keira_knightley"],["diane_kruger"],["frances_mcdormand"],["robert_mitchum"],["harrison_ford"],["colin_firth"],["denzel_washington"],["melanie_laurent"],["will_smith"],["henry_fonda"],["al_pacino"],["kevin_spacey"],["bette_davis"],["anthony_quinn"],["brie_larson"],["edward_norton"],["jamie_foxx"],["daisy_ridley"],["martin_sheen"],["scarlett_johansson"],["carrie_fisher"],["peter_o'toole"],["john_wayne"],["diane_keaton"],["julie_delpy"],["lauren_cohan"],["faye_dunaway"],["vera_farmiga"],["shelley_duvall"],["rooney_mara"],["anne_hathaway"],["robert_downey_jr."],["kim_novak"],["christopher_plummer"],["charles_laughton"],["saoirse_ronan"],["anna_kendrick"],["javier_bardem"],["rosamund_pike"],["alec_guinness_res"],["morgan_freeman"],["robin_wright"],["virginia_cherrill"],["john_goodman"],["kaya_scodelario"],["uma_thurman"],["alec_guinness"],["nicole_kidman"],["milla_jovovich"],["christoph_waltz"],["russell_crowe"],["charles_chaplin"],["dustin_hoffman"],["cate_blanchett"],["hilary_swank"],["emma_watson"],["elliot_page"],["jennifer_jason_leigh"],["jennifer_aniston"],["lea_seydoux"],["emma_stone"],["sidney_poitier"],["james_stewart"],["marlene_dietrich"],["joe_pesci"],["anthony_hopkins"],["richard_burton"],["philip_seymour_hoffman"],["liv_ullmann"],["peter_sellers"],["paul_newman"],["heath_ledger"],["matthew_mcconaughey"],["katherine_parkinson"],["maggie_smith"],["james_cagney"],["laurence_olivier"],["michelle_pfeiffer"],["elizabeth_olsen"],["buster_keaton"],["robert_de_niro"],["gloria_swanson"],["sally_hawkins"],["tilda_swinton"],["ingrid_bergman"],["vivien_leigh"],["don_cheadle"],["clint_eastwood"],["evangeline_lilly"],["gary_oldman"],["alicia_vikander"],["rachel_mcadams"],["viola_davis"],["bibi_andersson"],["talia_shire"],["jennifer_connelly"],["alan_rickman"],["robin_williams"],["helena_bonham_carter"],["olga_kurylenko"],["katheryn_winnick"],["geoffrey_rush"],["audrey_tautou"],["kate_winslet"],["jon_voight"],["sigourney_weaver"],["michael_douglas"],["ch ...

# %%
#Try to apply it to your embedding dataset and let me know
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Calculate t-SNE embedding
tsne = TSNE(n_components=2, random_state=42)
XY_tsne = tsne.fit_transform(deepface_vectors)
XY_tsne

# %%
# select the vector by your choice
desired_vector = XY_tsne[0]
desired_vector[0]
# Out:
# -0.16557075

# %%
# Center the t-SNE space on the desired vector
XY_tsne_centered = XY_tsne - np.mean(XY_tsne, axis=0) + desired_vector

new_desired_vector = XY_tsne_centered[0]

plotting_df = pd.concat([deepface_df['name'], pd.DataFrame(XY_tsne_centered)], axis=1)
plotting_df.columns = ["name", "X","Y"]

# %%
plotting_df
# Out:
#                    name         X          Y
# 0         ellen_burstyn -0.537749 -10.858600
# 1         julia_roberts  1.421389  -5.354323
# 2          meryl_streep -0.838155  -1.681599
# 3           jack_lemmon -3.752321  -1.004141
# 4     jennifer_lawrence  3.292961  -7.510081
# ..                  ...       ...        ...
# 196     octavia_spencer  1.647058  -4.285516
# 197          joan_allen -2.581752  -0.733440
# 198         bill_murray -1.398767  -3.903929
# 199        jeremy_irons  0.636901  -1.977958
# 200  edward_g._robinson  1.038399  -3.005701
#
# [201 rows x 3 columns]

# %%
fig = px.scatter(x=plotting_df["X"], y=plotting_df["Y"], color_discrete_sequence=['blue'], hover_name=plotting_df["name"])
# fig = px.scatter(XY_tsne["X"], XY_tsne["Y"],  color_discrete_sequence=['blue'],hover_name=plotting_df["name"])


fig.add_annotation(x=new_desired_vector[0], y=new_desired_vector[1],
            text="hidden celebrity",
            bgcolor="red",
            showarrow=True,
            arrowhead=1)
fig.show()
# Out:
# <div>                            <div id="76fa5e13-9c86-422d-9ce2-4ed9d9bbb8ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76fa5e13-9c86-422d-9ce2-4ed9d9bbb8ef")) {                    Plotly.newPlot(                        "76fa5e13-9c86-422d-9ce2-4ed9d9bbb8ef",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ellen_burstyn","julia_roberts","meryl_streep","jack_lemmon","jennifer_lawrence","kate_mara","adele_exarchopoulos","marilyn_monroe","michael_caine","spencer_tracy","mel_gibson","amanda_plummer","johnny_depp","brad_pitt","demi_moore","jessica_chastain","charlize_theron","george_c._scott","gene_hackman","benicio_del_toro","gene_kelly","samuel_l._jackson","tom_hanks","emmy_rossum","janet_leigh","steve_mcqueen","gary_cooper","orson_welles","maggie_gyllenhaal","tommy_lee_jones","jeff_bridges","naomi_watts","alyson_hannigan","rachel_weisz","ralph_fiennes","hailee_steinfeld","alan_arkin","kirk_douglas","jim_carrey","joaquin_phoenix","robert_redford","felicity_jones","kim_basinger","kirsten_dunst","natalie_portman","albert_finney","matt_damon","cameron_diaz","sharon_stone","charlton_heston","grace_kelly","julia_louis-dreyfus","jodie_foster","marion_cotillard","gregory_peck","humphrey_bogart","burt_lancaster","marlon_brando","margot_robbie","james_dean","liam_neeson","amy_adams","chloe_grace_moretz","william_holden","elizabeth_banks","woody_allen","leonardo_dicaprio","christopher_walken","daniel_day-lewis","jack_nicholson","sean_connery","peter_finch","ian_mckellen","jason_robards","angelina_jolie","ben_kingsley","tom_cruise","mia_farrow","julianne_moore","cary_grant","sean_penn","blake_lively","keira_knightley","diane_kruger","frances_mcdormand","robert_mitchum","harrison_ford","colin_firth","denzel_washington","melanie_laurent","will_smith","henry_fonda","al_pacino","kevin_spacey","bette_davis","anthony_quinn","brie_larson","edward_norton","jamie_foxx","daisy_ridley","martin_sheen","scarlett_johansson","carrie_fisher","peter_o'toole","john_wayne","diane_keaton","julie_delpy","lauren_cohan","faye_dunaway","vera_farmiga","shelley_duvall","rooney_mara","anne_hathaway","robert_downey_jr.","kim_novak","christopher_plummer","charles_laughton","saoirse_ronan","anna_kendrick","javier_bardem","rosamund_pike","alec_guinness_res","morgan_freeman","robin_wright","virginia_cherrill","john_goodman","kaya_scodelario","uma_thurman","alec_guinness","nicole_kidman","milla_jovovich","christoph_waltz","russell_crowe","charles_chaplin","dustin_hoffman","cate_blanchett","hilary_swank","emma_watson","elliot_page","jennifer_jason_leigh","jennifer_aniston","lea_seydoux","emma_stone","sidney_poitier","james_stewart","marlene_dietrich","joe_pesci","anthony_hopkins","richard_burton","philip_seymour_hoffman","liv_ullmann","peter_sellers","paul_newman","heath_ledger","matthew_mcconaughey","katherine_parkinson","maggie_smith","james_cagney","laurence_olivier","michelle_pfeiffer","elizabeth_olsen","buster_keaton","robert_de_niro","gloria_swanson","sally_hawkins","tilda_swinton","ingrid_bergman","vivien_leigh","don_cheadle","clint_eastwood","evangeline_lilly","gary_oldman","alicia_vikander","rachel_mcadams","viola_davis","bibi_andersson","talia_shire","jennifer_connelly","alan_rickman","robin_williams","helena_bonham_carter","olga_kurylenko","katheryn_winnick","geoffrey_rush","audrey_tautou","kate_winslet","jon_voight","sigourney_weaver","michael_douglas","christian_bale","carey_mulligan","eva_green","emily_blunt","hugh_jackman","robert_duvall","clark_gable","octavia_spencer","joan_allen","bill_murray","jeremy_irons","edward_g._robinson"],"legendgroup":"","marker":{"color":"blu ...
