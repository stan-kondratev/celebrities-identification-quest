# %% [markdown]
# # This is a notebook for embedding of vectors and generation of corresponding dataframes

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os

from sklearn.neighbors import NearestNeighbors

from sklearn.manifold import TSNE
import plotly.express as px

from deepface import DeepFace

# %% [markdown]
# ### Main function

# %%
def produce_dataframes(folder_path = '../raw_data/output_imdb_top100/'):
    # Generate file list. The folder with images should conatin only files with image extension such as jpg jpeg png etc.
    # The file names should be like name_surname.jpg. Ideally without diacritics. 
    file_list = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))]
    
    # Print progress
    for n, i in enumerate(file_list): print(n, os.path.splitext(os.path.basename(i))[0])
    
    # Create array of embeddings
    deepface_vectors = np.array([np.array(DeepFace.represent(i, model_name='VGG-Face', enforce_detection=False)[0]['embedding']) for i in file_list])
    
    # Generate cosine similarity arrays
    knn_deepface = NearestNeighbors(n_neighbors=len(deepface_vectors), metric='cosine', n_jobs=-1)
    knn_deepface.fit(deepface_vectors)
    deepface_distances, deepface_indices = knn_deepface.kneighbors(deepface_vectors)
    
    # Generate dataframes
    deepface_df = pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list]).rename(columns={0:'name'})
    deepface_df = pd.concat([deepface_df, pd.DataFrame(deepface_indices[:,1:])], axis=1)
    deepface_df[deepface_df.columns[1:]] = deepface_df[deepface_df.columns[1:]].applymap(lambda i: deepface_df.name.iloc[i])
    
    names_df = deepface_df.set_index('name').T

    distances_df = pd.concat([pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list])\
        .rename(columns={0:'name'}), pd.DataFrame(deepface_distances[:,1:])], axis=1).set_index('name').T

    indices_df = pd.concat([pd.DataFrame([os.path.splitext(os.path.basename(i))[0] for i in file_list])\
            .rename(columns={0:'name'}), pd.DataFrame(deepface_indices[:,1:])], axis=1).set_index('name').T

    scoring_df = distances_df.copy()
    
    tsne_1d = TSNE(n_components=1, random_state=0, perplexity=5) # used for plotting. Perplexity = 5 as the dataset has not so many values
    projections = tsne_1d.fit_transform(deepface_vectors, )

    projections_df = indices_df.T.reset_index().iloc[:,1:].applymap(lambda x: projections[x][0]).T
    projections_df.columns = scoring_df.columns
    projections_df
    
    return names_df, scoring_df, projections_df, indices_df

# %% [markdown]
# ### Just provide a path to a folder where you have images with your celebrities

# %%
names_df, scoring_df, projections_df, indices_df = produce_dataframes(folder_path='../raw_data/output_imdb_top100')
# Out:
# 0 ellen_burstyn
# 1 julia_roberts
# 2 liam_hemsworth
# 3 meryl_streep
# 4 jack_lemmon
# 5 jennifer_lawrence
# 6 kate_mara
# 7 adele_exarchopoulos
# 8 marilyn_monroe
# 9 michael_caine
# 10 spencer_tracy
# 11 mel_gibson
# 12 amanda_plummer
# 13 johnny_depp
# 14 brad_pitt
# 15 demi_moore
# 16 jessica_chastain
# 17 jimmy_fallon
# 18 charlize_theron
# 19 george_c._scott
# 20 gene_hackman
# 21 benicio_del_toro
# 22 gene_kelly
# 23 samuel_l._jackson
# 24 tom_hanks
# 25 emmy_rossum
# 26 janet_leigh
# 27 steve_mcqueen
# 28 gary_cooper
# 29 orson_welles
# 30 maggie_gyllenhaal
# 31 tommy_lee_jones
# 32 jeff_bridges
# 33 naomi_watts
# 34 alyson_hannigan
# 35 rachel_weisz
# 36 ralph_fiennes
# 37 hailee_steinfeld
# 38 alan_arkin
# 39 kirk_douglas
# 40 jim_carrey
# 41 joaquin_phoenix
# 42 robert_redford
# 43 felicity_jones
# 44 kim_basinger
# 45 kirsten_dunst
# 46 natalie_portman
# 47 albert_finney
# 48 matt_damon
# 49 cameron_diaz
# 50 sharon_stone
# 51 charlton_heston
# 52 grace_kelly
# 53 julia_louis-dreyfus
# 54 jodie_foster
# 55 marion_cotillard
# 56 gregory_peck
# 57 humphrey_bogart
# 58 burt_lancaster
# 59 marlon_brando
# 60 margot_robbie
# 61 james_dean
# 62 liam_neeson
# 63 amy_adams
# 64 chloe_grace_moretz
# 65 william_holden
# 66 elizabeth_banks
# 67 woody_allen
# 68 leonardo_dicaprio
# 69 christopher_walken
# 70 daniel_day-lewis
# 71 jack_nicholson
# 72 sean_connery
# 73 peter_finch
# 74 ian_mckellen
# 75 jason_robards
# 76 angelina_jolie
# 77 emma_mackey
# 78 ben_kingsley
# 79 tom_cruise
# 80 mia_farrow
# 81 julianne_moore
# 82 cary_grant
# 83 sean_penn
# 84 blake_lively
# 85 keira_knightley
# 86 diane_kruger
# 87 frances_mcdormand
# 88 robert_mitchum
# 89 harrison_ford
# 90 colin_firth
# 91 denzel_washington
# 92 melanie_laurent
# 93 will_smith
# 94 henry_fonda
# 95 al_pacino
# 96 kevin_spacey
# 97 bette_davis
# 98 anthony_quinn
# 99 brie_larson
# 100 edward_norton
# 101 jamie_foxx
# 102 daisy_ridley
# 103 martin_sheen
# 104 scarlett_johansson
# 105 carrie_fisher
# 106 peter_o'toole
# 107 john_wayne
# 108 diane_keaton
# 109 julie_delpy
# 110 lauren_cohan
# 111 faye_dunaway
# 112 vera_farmiga
# 113 shelley_duvall
# 114 rooney_mara
# 115 anne_hathaway
# 116 robert_downey_jr.
# 117 kim_novak
# 118 christopher_plummer
# 119 lucy_liu
# 120 charles_laughton
# 121 saoirse_ronan
# 122 anna_kendrick
# 123 javier_bardem
# 124 rosamund_pike
# 125 morgan_freeman
# 126 robin_wright
# 127 virginia_cherrill
# 128 john_goodman
# 129 kaya_scodelario
# 130 uma_thurman
# 131 alec_guinness
# 132 nicole_kidman
# 133 milla_jovovich
# 134 christoph_waltz
# 135 russell_crowe
# 136 charles_chaplin
# 137 dustin_hoffman
# 138 cate_blanchett
# 139 hilary_swank
# 140 emma_watson
# 141 elliot_page
# 142 jennifer_jason_leigh
# 143 jennifer_aniston
# 144 lea_seydoux
# 145 emma_stone
# 146 sidney_poitier
# 147 james_stewart
# 148 marlene_dietrich
# 149 joe_pesci
# 150 anthony_hopkins
# 151 richard_burton
# 152 philip_seymour_hoffman
# 153 liv_ullmann
# 154 peter_sellers
# 155 paul_newman
# 156 chris_hemsworth
# 157 heath_ledger
# 158 matthew_mcconaughey
# 159 katherine_parkinson
# 160 maggie_smith
# 161 james_cagney
# 162 laurence_olivier
# 163 michelle_pfeiffer
# 164 elizabeth_olsen
# 165 buster_keaton
# 166 robert_de_niro
# 167 gloria_swanson
# 168 sally_hawkins
# 169 tilda_swinton
# 170 ingrid_bergman
# 171 vivien_leigh
# 172 don_cheadle
# 173 clint_eastwood
# 174 evangeline_lilly
# 175 jaime_king
# 176 gary_oldman
# 177 alicia_vikander
# 178 rachel_mcadams
# 179 viola_davis
# 180 bibi_andersson
# 181 talia_shire
# 182 jennifer_connelly
# 183 alan_rickman
# 184 samara_weaving
# 185 robin_williams
# 186 helena_bonham_carter
# 187 olga_kurylenko
# 188 katheryn_winnick
# 189 geoffrey_rush
# 190 audrey_tautou
# 191 kate_winslet
# 192 jon_voight
# 193 sigourney_weaver
# 194 michael_douglas
# 195 christian_bale
# 196 carey_mulligan
# 197 eva_green
# 198 emily_blunt
# 199 hugh_jackman
# 200 robert_duvall
# 201 clark_gable
# 202 octavia_spencer
# 203 joan_allen
# 204 bill_murray
# 205 jeremy_irons
# 206 edward_g._robinson

# %%
# Save to file
names_df.to_csv('../raw_data/names.csv')
scoring_df.to_csv('../raw_data/scoring.csv')
projections_df.to_csv('../raw_data/projections.csv')
indices_df.to_csv('../raw_data/indices.csv')

# %%
# For scores analysis
def image_check(name, names_df=names_df, scoring_df=scoring_df):
    names = names_df[name]
    scores = scoring_df[name]
    return pd.concat([names,scores], axis=1)

# %%
names_df.head()
# Out:
# name     ellen_burstyn     julia_roberts     liam_hemsworth  \
# 0        peter_o'toole    julianne_moore    chris_hemsworth
# 1     sigourney_weaver  evangeline_lilly         matt_damon
# 2         sharon_stone      hilary_swank       heath_ledger
# 3           joan_allen      faye_dunaway  leonardo_dicaprio
# 4         maggie_smith      jodie_foster          brad_pitt
#
# name       meryl_streep     jack_lemmon   jennifer_lawrence         kate_mara  \
# 0         nicole_kidman    john_goodman     melanie_laurent       emma_watson
# 1           naomi_watts   alec_guinness         johnny_depp    bibi_andersson
# 2        carey_mulligan  robert_mitchum      carey_mulligan      robin_wright
# 3     jennifer_lawrence      john_wayne         emma_mackey       lea_seydoux
# 4        angelina_jolie       joe_pesci  chloe_grace_moretz  jessica_chastain
#
# name adele_exarchopoulos     marilyn_monroe   michael_caine  ...  \
# 0            emmy_rossum          kim_novak   peter_o'toole  ...
# 1            emily_blunt   marlene_dietrich      jon_voight  ...
# 2         olga_kurylenko       meryl_streep   robert_duvall  ...
# 3              eva_green     angelina_jolie    john_goodman  ...
# 4        elizabeth_olsen  virginia_cherrill  jack_nicholson  ...
#
# name          eva_green          emily_blunt         hugh_jackman  \
# 0           julie_delpy         jodie_foster      chris_hemsworth
# 1     jennifer_connelly  adele_exarchopoulos  matthew_mcconaughey
# 2           emma_watson      alyson_hannigan            brad_pitt
# 3         saoirse_ronan       julianne_moore            tom_hanks
# 4             amy_adams     marion_cotillard        russell_crowe
#
# name    robert_duvall       clark_gable  octavia_spencer         joan_allen  \
# 0     anthony_hopkins  laurence_olivier      viola_davis       maggie_smith
# 1      robert_redford      sean_connery      don_cheadle  michelle_pfeiffer
# 2       spencer_tracy     james_stewart  anthony_hopkins        uma_thurman
# 3       jason_robards       henry_fonda   morgan_freeman     amanda_plummer
# 4       michael_caine        gene_kelly     ian_mckellen      ellen_burstyn
#
# name     bill_murray            jeremy_irons edward_g._robinson
# 0       kevin_spacey         christoph_waltz      albert_finney
# 1     robin_williams             henry_fonda    george_c._scott
# 2      russell_crowe        daniel_day-lewis   charles_laughton
# 3         jim_carrey  philip_seymour_hoffman        jack_lemmon
# 4       john_goodman          clint_eastwood        elliot_page
#
# [5 rows x 207 columns]

# %%
scoring_df
# Out:
# name  ellen_burstyn  julia_roberts  liam_hemsworth  meryl_streep  jack_lemmon  \
# 0          0.393694       0.363772        0.255083      0.140787     0.223894
# 1          0.401021       0.378794        0.333176      0.162265     0.271252
# 2          0.405558       0.386467        0.411394      0.177884     0.282591
# 3          0.406163       0.398142        0.423737      0.199677     0.283379
# 4          0.426537       0.399806        0.445019      0.208655     0.288183
# ..              ...            ...             ...           ...          ...
# 201        0.844788       0.940765        0.957998      0.864209     0.926329
# 202        0.859890       0.955673        0.989778      0.876334     0.928763
# 203        0.888442       0.970522        0.990261      0.894891     0.954474
# 204        0.895959       0.975988        1.038924      0.896980     0.956301
# 205        0.939028       1.016962        1.059219      0.946386     1.044643
#
# name  jennifer_lawrence  kate_mara  adele_exarchopoulos  marilyn_monroe  \
# 0              0.078622   0.295861             0.370248        0.331272
# 1              0.103272   0.368113             0.393614        0.382534
# 2              0.113155   0.398993             0.414373        0.400170
# 3              0.115136   0.399680             0.421046        0.415377
# 4              0.139725   0.417491             0.447967        0.430180
# ..                  ...        ...                  ...             ...
# 201            0.894636   0.956685             0.838640        0.990504
# 202            0.904712   0.959069             0.842059        0.993273
# 203            0.906295   0.963079             0.846488        1.013070
# 204            0.918412   0.977768             0.871848        1.059219
# 205            0.928349   0.980076             0.873602        1.086513
#
# name  michael_caine  ...  eva_green  emily_blunt  hugh_jackman  robert_duvall  \
# 0          0.226414  ...   0.352416     0.390768      0.309979       0.186653
# 1          0.242548  ...   0.384863     0.393614      0.323990       0.203195
# 2          0.249888  ...   0.387402     0.399558      0.325256       0.244336
# 3          0.260621  ...   0.390164     0.417410      0.342058       0.246964
# 4          0.270665  ...   0.406319     0.428567      0.357280       0.249888
# ..              ...  ...        ...          ...           ...            ...
# 201        0.933551  ...   0.832967     0.892392      0.949379       0.781702
# 202        0.942540  ...   0.841539     0.893257      0.950903       0.782696
# 203        0.963079  ...   0.843241     0.896073      0.991371       0.810398
# 204        0.982461  ...   0.854757     0.909300      0.995844       0.830546
# 205        1.001975  ...   0.890031     0.914694      1.013070       0.836726
#
# name  clark_gable  octavia_spencer  joan_allen  bill_murray  jeremy_irons  \
# 0        0.293713         0.343306    0.370138     0.190542      0.254345
# 1        0.309910         0.494182    0.385836     0.241941      0.308656
# 2        0.328509         0.529435    0.388018     0.243102      0.311805
# 3        0.334536         0.536601    0.402839     0.289938      0.314134
# 4        0.336980         0.567086    0.406163     0.293471      0.322536
# ..            ...              ...         ...          ...           ...
# 201      0.956859         0.954681    0.799548     0.869307      0.902664
# 202      0.980053         0.954964    0.804758     0.877596      0.907769
# 203      0.983847         0.976027    0.816429     0.897704      0.919542
# 204      0.995343         0.989778    0.816469     0.925115      0.934413
# 205      1.157254         0.999889    0.833843     1.014898      0.965063
#
# name  edward_g._robinson
# 0               0.373177
# 1               0.405609
# 2               0.405720
# 3               0.405788
# 4               0.413066
# ..                   ...
# 201             0.895595
# 202             0.929150
# 203             0.940765
# 204             0.944075
# 205             1.055245
#
# [206 rows x 207 columns]

# %%
image_check('margot_robbie')
# Out:
#          margot_robbie  margot_robbie
# 0     hailee_steinfeld       0.326541
# 1       samara_weaving       0.354098
# 2          naomi_watts       0.356592
# 3         daisy_ridley       0.360571
# 4      charlize_theron       0.387094
# ..                 ...            ...
# 201    charlton_heston       0.858020
# 202  samuel_l._jackson       0.859447
# 203      michael_caine       0.871580
# 204        viola_davis       0.872041
# 205       maggie_smith       0.877991
#
# [206 rows x 2 columns]

# %%
projections_df
# Out:
# name  ellen_burstyn  julia_roberts  liam_hemsworth  meryl_streep  jack_lemmon  \
# 0         -5.847637       7.192966      -46.503056     27.585815   -14.197795
# 1         -3.770584       8.548803      -47.497498     27.637901   -17.027782
# 2         -2.187772      42.972565      -27.665766     28.691648   -33.132259
# 3          5.769936      -2.402707      -47.549248     28.582142   -13.423986
# 4         -8.277208       6.481924      -45.268753     30.494530   -33.508835
# ..              ...            ...             ...           ...          ...
# 201       30.737099     -15.171880       11.224054    -45.268753    40.929520
# 202      -46.592503     -35.074825        2.125116     43.648884    43.648884
# 203       29.779570       3.953416       -8.277208    -46.592503    34.636566
# 204       31.605349     -36.028496        8.548803    -46.503056    42.329990
# 205       31.433588     -35.519753       25.829344      8.548803     8.548803
#
# name  jennifer_lawrence  kate_mara  adele_exarchopoulos  marilyn_monroe  \
# 0             28.443249  15.308876            21.569750       26.108665
# 1             18.340479  15.025901            20.585474       25.694407
# 2             28.691648  24.607462            21.876064       26.767708
# 3             29.779570  34.669415            23.508514       30.494530
# 4             30.360929  11.865150            21.064133       17.206284
# ..                  ...        ...                  ...             ...
# 201          -45.268753 -32.050415           -35.519753      -45.268753
# 202          -23.940500  -4.791681           -21.825199      -25.649073
# 203          -25.649073  -7.877814           -36.048618      -44.558472
# 204            8.548803 -13.423986            -0.249916      -46.592503
# 205          -44.558472   0.184028           -34.080925      -46.503056
#
# name  michael_caine  ...  eva_green  emily_blunt  hugh_jackman  robert_duvall  \
# 0         -5.847637  ...  11.746453     6.481924    -46.503056      -9.912743
# 1         -8.263890  ...  23.698853    21.816792    -43.950195     -30.168154
# 2         -9.866195  ...  15.308876    20.497644    -45.268753     -39.824951
# 3        -14.197795  ...  37.669670     7.192966    -23.326687     -40.362965
# 4         -6.705454  ...  23.222748    20.451962    -25.035971      -7.877814
# ..              ...  ...        ...          ...           ...            ...
# 201       15.308876  ...   2.031495    -0.249916     30.890013      30.737099
# 202        8.548803  ...   0.184028   -46.592503     30.737099      31.605349
# 203       15.199759  ...   2.125116   -35.519753      8.548803      34.636566
# 204       34.636566  ...  -0.859690   -36.048618     30.360929      31.433588
# 205       31.433588  ...  -0.249916   -35.074825     25.829344       8.548803
#
# name  clark_gable  octavia_spencer  joan_allen  bill_murray  jeremy_irons  \
# 0      -35.519753         2.031495   -8.277208   -23.146187    -20.010386
# 1      -42.034348        -0.060083    6.369839   -12.828065    -34.080925
# 2      -32.049522        -9.912743   -3.270234   -25.035971    -20.143358
# 3      -34.080925         0.184028  -29.809515   -24.055618    -20.793697
# 4      -28.860556       -11.147629   -5.725354   -14.197795    -17.471899
# ..            ...              ...         ...          ...           ...
# 201      8.257996       -35.519753   21.876064    30.737099     30.890013
# 202     34.636566       -36.355904   19.078037    30.890013     30.360929
# 203     42.329990       -36.028496   29.779570    31.433588     34.636566
# 204     43.648884       -46.592503   31.605349    34.636566     31.433588
# 205      8.548803       -36.048618   31.433588     8.548803      8.548803
#
# name  edward_g._robinson
# 0             -14.826070
# 1             -16.429581
# 2             -16.108551
# 3             -14.366277
# 4               3.953416
# ..                   ...
# 201             6.369839
# 202             8.257996
# 203             8.904810
# 204            43.648884
# 205             8.548803
#
# [206 rows x 207 columns]

# %% [markdown]
# ### Plotting test

# %%
hidden_celebrity = 'margot_robbie' # Pass a hidden celebrity for a test. 
names_df=pd.read_csv("../raw_data/names.csv")
indices_df=pd.read_csv("../raw_data/indices.csv")
scoring_df=pd.read_csv("../raw_data/scoring.csv")
projections_df=pd.read_csv("../raw_data/projections.csv")
plotting_df = pd.concat([names_df[hidden_celebrity], indices_df[hidden_celebrity], scoring_df[hidden_celebrity], projections_df[hidden_celebrity]], axis=1)
plotting_df.columns = ['names','indices', 'distances', 'projections']
plotting_df['radial_projections'] = plotting_df['projections'].apply(lambda x: (x- plotting_df['projections'].max())/(plotting_df['projections'].min()-plotting_df['projections'].max())*360)
plotting_df
# Out:
#                  names  indices  distances  projections  radial_projections
# 0       samara_weaving      184   0.354098    44.562260            7.603532
# 1          naomi_watts       33   0.356592    27.637901           72.352058
# 2         daisy_ridley      102   0.360571    31.433588           57.830673
# 3      charlize_theron       18   0.387094    41.601143           18.932054
# 4     katheryn_winnick      188   0.401245    30.737099           60.495272
# ..                 ...      ...        ...          ...                 ...
# 201    charlton_heston       51   0.858020    -4.791681          196.419837
# 202  samuel_l._jackson       23   0.859447    -0.249916          179.044136
# 203      michael_caine        9   0.871580    -7.877814          208.226640
# 204        viola_davis      179   0.872041     2.031495          170.316008
# 205       maggie_smith      160   0.877991    -8.277208          209.754624
#
# [206 rows x 5 columns]

# %%
fig = px.scatter_polar(plotting_df, r='distances', theta="radial_projections", hover_data='names')
fig.show()
# Out:
# <div>                            <div id="b9362e6c-01c9-45f9-bea0-1a4d7b847d09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9362e6c-01c9-45f9-bea0-1a4d7b847d09")) {                    Plotly.newPlot(                        "b9362e6c-01c9-45f9-bea0-1a4d7b847d09",                        [{"customdata":[["samara_weaving"],["naomi_watts"],["daisy_ridley"],["charlize_theron"],["katheryn_winnick"],["lauren_cohan"],["natalie_portman"],["emmy_rossum"],["keira_knightley"],["hailee_steinfeld"],["katherine_parkinson"],["rooney_mara"],["scarlett_johansson"],["emma_watson"],["olga_kurylenko"],["carey_mulligan"],["audrey_tautou"],["vivien_leigh"],["brie_larson"],["emma_stone"],["kate_mara"],["nicole_kidman"],["angelina_jolie"],["janet_leigh"],["elizabeth_olsen"],["rachel_mcadams"],["diane_kruger"],["emma_mackey"],["kate_winslet"],["jennifer_lawrence"],["elizabeth_banks"],["robin_wright"],["rachel_weisz"],["chloe_grace_moretz"],["alicia_vikander"],["ingrid_bergman"],["jennifer_connelly"],["bibi_andersson"],["adele_exarchopoulos"],["kim_basinger"],["amy_adams"],["cate_blanchett"],["meryl_streep"],["anne_hathaway"],["jennifer_jason_leigh"],["milla_jovovich"],["edward_g._robinson"],["saoirse_ronan"],["melanie_laurent"],["kaya_scodelario"],["johnny_depp"],["anna_kendrick"],["lucy_liu"],["jennifer_aniston"],["julie_delpy"],["vera_farmiga"],["eva_green"],["alyson_hannigan"],["frances_mcdormand"],["uma_thurman"],["lea_seydoux"],["elliot_page"],["shelley_duvall"],["virginia_cherrill"],["hilary_swank"],["denzel_washington"],["sharon_stone"],["george_c._scott"],["leonardo_dicaprio"],["felicity_jones"],["marion_cotillard"],["kirsten_dunst"],["grace_kelly"],["tilda_swinton"],["kim_novak"],["matt_damon"],["gloria_swanson"],["jessica_chastain"],["jimmy_fallon"],["charles_chaplin"],["demi_moore"],["peter_finch"],["will_smith"],["emily_blunt"],["michelle_pfeiffer"],["rosamund_pike"],["christopher_walken"],["gregory_peck"],["joaquin_phoenix"],["maggie_gyllenhaal"],["heath_ledger"],["christoph_waltz"],["julianne_moore"],["helena_bonham_carter"],["gary_oldman"],["marlene_dietrich"],["liam_hemsworth"],["james_dean"],["buster_keaton"],["gary_cooper"],["orson_welles"],["bette_davis"],["anthony_hopkins"],["tom_hanks"],["jodie_foster"],["william_holden"],["colin_firth"],["sally_hawkins"],["albert_finney"],["burt_lancaster"],["mia_farrow"],["sean_connery"],["ellen_burstyn"],["kevin_spacey"],["marilyn_monroe"],["sigourney_weaver"],["robert_downey_jr."],["richard_burton"],["robert_duvall"],["chris_hemsworth"],["anthony_quinn"],["robert_mitchum"],["benicio_del_toro"],["jaime_king"],["christian_bale"],["gene_kelly"],["gene_hackman"],["edward_norton"],["blake_lively"],["alan_rickman"],["humphrey_bogart"],["bill_murray"],["clint_eastwood"],["liam_neeson"],["ian_mckellen"],["cameron_diaz"],["matthew_mcconaughey"],["clark_gable"],["sidney_poitier"],["peter_sellers"],["laurence_olivier"],["joan_allen"],["russell_crowe"],["james_cagney"],["alan_arkin"],["sean_penn"],["martin_sheen"],["joe_pesci"],["woody_allen"],["hugh_jackman"],["amanda_plummer"],["alec_guinness"],["talia_shire"],["daniel_day-lewis"],["ben_kingsley"],["marlon_brando"],["robert_de_niro"],["john_goodman"],["tommy_lee_jones"],["dustin_hoffman"],["octavia_spencer"],["jim_carrey"],["philip_seymour_hoffman"],["spencer_tracy"],["al_pacino"],["jeff_bridges"],["jon_voight"],["charles_laughton"],["ralph_fiennes"],["javier_bardem"],["liv_ullmann"],["kirk_douglas"],["robert_redford"],["julia_louis-dreyfus"],["robin_williams"],["paul_newman"],["jack_lemmon"],["carrie_fisher"],["steve_mcqueen"],["julia_roberts"],["brad_pitt"],["tom_cruise"],["geoffrey_rush"],["evangeline_lilly"],["jason_robards"],["mel_gibson"],["diane_keaton"],["peter_o'toole"],["jamie_foxx"],["henry_fonda"],["mich ...

# %% [markdown]
# ### Query test

# %%
def celeb_and_score_query(celebrity, hidden_celebrity=hidden_celebrity, names_df=names_df, score_df=scoring_df):
    celeb_rank = names_df[hidden_celebrity][names_df[hidden_celebrity] == celebrity].index
    celeb_score = scoring_df[hidden_celebrity].loc[celeb_rank].iloc[0]
    return celebrity, celeb_score

# %%
celeb_and_score_query('margot_robbie')
